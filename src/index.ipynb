# %% [markdown]
# <div style="float:right;padding-top:20px">
#    <img src="https://www.enib.fr/images/logo-enib-accueil.jpg" style="width:120px"/>
# </div>
#
# # Second Order Analog Filters
#
# <div style="padding-top: 40px">
# <div class="alert alert-info" role="alert" >
#  <ul>
#      <li>This page contains a list of passive and active analog filters. For each filter, a notebook file is available to compute the values of the filter components from a list of filter specifications.</li>
#     </ul>
# </div>
# </div>

# %% [markdown]
# ## Passive Filters
#
#
# <table class="table">
#   <thead>
#     <tr>
#       <th scope="col" >Structure</th>
#       <th scope="col">Type</th>
#       <th scope="col">Circuit</th>
#       <th scope="col">Action</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr style="background: none">
#         <th scope="row" >RC-RC</th>
#         <td>Lowpass</td>
#         <td><img src="./passive_filters/img/RC_RC_LP.svg" width="100px"></img></td>
#         <td><a href="./passive_filters/RC_RC_LP.ipynb" class="btn btn-primary" style="text-decoration: none">Select</a></td>
#     </tr style="background: none">
#     <tr style="background: none">
#         <th scope="row">RC-RC</th>
#         <td>Highpass</td>
#         <td><img src="./passive_filters/img/RC_RC_HP.svg" width="100px"></img></td>
#         <td><a href="./passive_filters/RC_RC_HP.ipynb" class="btn btn-primary" style="text-decoration: none">Select</a></td>
#     </tr>
#     <tr style="background: none">
#         <th scope="row">RC-RC</th>
#         <td>Bandpass</td>
#         <td><img src="./passive_filters/img/RC_RC_BP.svg" width="100px"></img></td>
#         <td><a href="./passive_filters/RC_RC_BP.ipynb" class="btn btn-primary" style="text-decoration: none">Select</a></td>
#     </tr>
#     <tr style="background: none">
#         <th scope="row">RLC</th>
#         <td>Lowpass</td>
#         <td><img src="./passive_filters/img/RLC_LP.svg" width="100px"></img></td>
#             <td><a href="./passive_filters/RLC_LP.ipynb" class="btn btn-primary" style="text-decoration: none">Select</a></td>
#     </tr>
#     <tr style="background: none">
#         <th scope="row">RLC</th>
#         <td>Highpass</td>
#         <td><img src="./passive_filters/img/RLC_HP.svg" width="100px"></img></td>
#         <td><a href="./passive_filters/RLC_HP.ipynb" class="btn btn-primary" style="text-decoration: none">Select</a></td>
#     </tr>
#     <tr style="background: none">
#         <th scope="row">RLC</th>
#         <td>Bandpass (type1)</td>
#         <td><img src="./passive_filters/img/RLC_BP1.svg" width="100px"></img></td>
#         <td><a href="./passive_filters/RLC_BP1.ipynb" class="btn btn-primary" style="text-decoration: none">Select</a></td>
#     </tr>
#     <tr style="background: none">
#         <th scope="row">RLC</th>
#         <td>Bandpass (type2)</td>
#         <td><img src="./passive_filters/img/RLC_BP2.svg" width="100px"></img></td>
#         <td><a href="./passive_filters/RLC_BP2.ipynb" class="btn btn-primary" style="text-decoration: none">Select</a></td>
#     </tr>
#     <tr style="background: none">
#         <th scope="row">RLC</th>
#         <td>Notch</td>
#         <td><img src="./passive_filters/img/RLC_Notch.svg" width="100px"></img></td>
#         <td><a href="./passive_filters/RLC_Notch.ipynb" class="btn btn-primary" style="text-decoration: none">Select</a></td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Active Filters
#
#
# <table class="table">
#   <thead>
#     <tr>
#       <th scope="col">Structure</th>
#       <th scope="col">Type</th>
#       <th scope="col">Circuit</th>
#       <th scope="col">Action</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr style="background: none">
#         <th scope="row">Rauch</th>
#         <td>Lowpass</td>
#         <td><img src="./active_filters/img/Rauch_LP.svg" width="100px"></img></td>
#         <td><a href="./active_filters/Rauch_LP.ipynb" class="btn btn-primary" style="text-decoration: none">Select</a></td>
#     </tr>
#     <tr style="background: none">
#         <th scope="row">Rauch</th>
#         <td>Highpass</td>
#         <td><img src="./active_filters/img/Rauch_HP.svg" width="100px"></img></td>
#         <td><a href="./active_filters/Rauch_HP.ipynb" class="btn btn-primary" style="text-decoration: none">Select</a></td>
#     </tr>
#     <tr style="background: none">
#         <th scope="row">Rauch</th>
#         <td>Bandpass</td>
#         <td><img src="./active_filters/img/Rauch_BP.svg" width="100px"></img></td>
#         <td><a href="./active_filters/Rauch_BP.ipynb" class="btn btn-primary" style="text-decoration: none">Select</a></td>
#     </tr>
#     <tr style="background: none">
#         <th scope="row">Sallen Key</th>
#         <td>Lowpass</td>
#         <td><img src="./active_filters/img/SK_BP.svg" width="100px"></img></td>
#         <td><a href="./active_filters/SK_BP.ipynb" class="btn btn-primary" style="text-decoration: none">Select</a></td>
#     </tr>
#     <tr style="background: none">
#         <th scope="row">Sallen Key</th>
#         <td>Highpass</td>
#         <td><img src="./active_filters/img/SK_BP.svg" width="100px"></img></td>
#         <td><a href="./active_filters/SK_BP.ipynb" class="btn btn-primary" style="text-decoration: none">Select</a></td>
#     </tr>
#     <tr style="background: none">
#         <th scope="row">Sallen Key</th>
#         <td>Bandpass</td>
#         <td><img src="./active_filters/img/SK_BP.svg" width="100px"></img></td>
#         <td><a href="./active_filters/SK_BP.ipynb" class="btn btn-primary" style="text-decoration: none">Select</a></td>
#     </tr>
#   </tbody>
# </table>
